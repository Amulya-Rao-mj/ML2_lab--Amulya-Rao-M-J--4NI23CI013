# %% [markdown]
# <a href="https://colab.research.google.com/github/Amulya-Rao-mj/ML2_lab--Amulya-Rao-M-J--4NI23CI013/blob/main/ML_lab3_FindS_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=[
    ['Sunny','hot','high','weak','no'],
    ['Sunny','hot','high','strong','yes'],
    ['overcast','hot','high','weak','yes'],
    ['rainy','mild','high','weak','yes'],
    ['rainy','cool','normal','weak','yes'],
    ['rainy','cool','normal','strong','no'],
    ['overcast','cool','normal','strong','yes'],
    ['sunny','mild','high','weak','no'],
    ['sunny','cool','normal','weak','yes'],
    ['rainy','mild','normal','weak','yes']
]
columns=['Outlook','Temperature','Humidity','wind','Playtennis']
df=pd.DataFrame(data,columns=columns)

x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
hypothesis=None
for i in range(len(x)):
    if y[i]=='yes':
      if hypothesis is None:
        hypothesis=x[i].copy()
      else:
        for j in range(len(hypothesis)):
          if hypothesis[j]!=x[i][j]:
            hypothesis[j]='?'
    print("step ",i+1,"hypothesis",hypothesis)
print(hypothesis)
# Out:
# step  1 hypothesis None
# step  2 hypothesis ['Sunny' 'hot' 'high' 'strong']
# step  3 hypothesis ['?' 'hot' 'high' '?']
# step  4 hypothesis ['?' '?' 'high' '?']
# step  5 hypothesis ['?' '?' '?' '?']
# step  6 hypothesis ['?' '?' '?' '?']
# step  7 hypothesis ['?' '?' '?' '?']
# step  8 hypothesis ['?' '?' '?' '?']
# step  9 hypothesis ['?' '?' '?' '?']
# step  10 hypothesis ['?' '?' '?' '?']
# ['?' '?' '?' '?']

# %%
import csv

def find_s(data):
    hypothesis = None

    for i, row in enumerate(data, start=1):
        row = [x.strip() for x in row]
        attributes = row[:-1]
        target = row[-1].lower()

        print("\nExample", i, ":", row)

        if target == "yes":
            if hypothesis is None:
                hypothesis = attributes.copy()
                print("Positive example")
                print("Initial hypothesis:", hypothesis)
            else:
                print("Positive example")
                for j in range(len(hypothesis)):
                    if hypothesis[j] != attributes[j]:
                        hypothesis[j] = "?"
                print("Updated hypothesis:", hypothesis)
        else:
            print("Negative example - ignored")

        print("Current hypothesis:", hypothesis)

    return hypothesis


filename = "sunny.csv"

with open(filename, "r") as file:
    reader = csv.reader(file)
    # Attempt to read header
    initial_header = next(reader)
    # Read the rest of the data
    all_data = list(reader)

# Correctly assign header and data based on whether initial_header was empty
if not initial_header and all_data:
    header = all_data[0]
    data = all_data[1:]
elif initial_header:
    header = initial_header
    data = all_data
else: # Case where file is entirely empty or only contained empty lines
    header = []
    data = []

if header:
    print("Attributes:", header[:-1])
    print("Target:", header[-1])
else:
    print("No header found.")

if data:
    hypothesis = find_s(data)
    print("\nFinal Hypothesis:")
    print(hypothesis)
else:
    print("\nNo data to process for Find-S algorithm.")
    hypothesis = None
# Out:
# Attributes: ['Sky', 'AirTemp', 'Humidity', 'Wind', 'Water', 'Forecast']
# Target: EnjoySport
#
# Example 1 : ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes']
# Positive example
# Initial hypothesis: ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
# Current hypothesis: ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
#
# Example 2 : ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes']
# Positive example
# Updated hypothesis: ['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
# Current hypothesis: ['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
#
# Example 3 : ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'No']
# Negative example - ignored
# Current hypothesis: ['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
#
# Example 4 : ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes']
# Positive example
# Updated hypothesis: ['Sunny', 'Warm', '?', 'Strong', '?', '?']
# Current hypothesis: ['Sunny', 'Warm', '?', 'Strong', '?', '?']
#
# ...

# %%
#Using FindS algorithm on Loan Approval Dataset

import csv

def find_s(data):
    hypothesis = None

    for i, row in enumerate(data, start=1):
        row = [x.strip() for x in row]
        attributes = row[:-1]
        target = row[-1].lower()

        print("\nExample", i, ":", row)

        if target == "yes":
            if hypothesis is None:
                hypothesis = attributes.copy()
                print("Positive example")
                print("Initial hypothesis:", hypothesis)
            else:
                print("Positive example")
                for j in range(len(hypothesis)):
                    if hypothesis[j] != attributes[j]:
                        hypothesis[j] = "?"
                print("Updated hypothesis:", hypothesis)
        else:
            print("Negative example - ignored")

        print("Current hypothesis:", hypothesis)

    return hypothesis


filename = "loan_approval_dataset.csv"

with open(filename, "r") as file:
    reader = csv.reader(file)
    header = next(reader)
    data = list(reader)

print("Attributes:", header[:-1])
print("Target:", header[-1])

hypothesis = find_s(data)

print("\nFinal Hypothesis:")
print(hypothesis)
# Out:
# Attributes: ['Age', 'Job', 'Income', 'CreditHistory', 'Collateral']
# Target: Approved
#
# Example 1 : ['Youth', 'Employed', 'High', 'Good', 'None', 'Yes']
# Positive example
# Initial hypothesis: ['Youth', 'Employed', 'High', 'Good', 'None']
# Current hypothesis: ['Youth', 'Employed', 'High', 'Good', 'None']
#
# Example 2 : ['Middle-Aged', 'Unemployed', 'Medium', 'Bad', 'None', 'No']
# Negative example - ignored
# Current hypothesis: ['Youth', 'Employed', 'High', 'Good', 'None']
#
# Example 3 : ['Senior', 'Employed', 'Low', 'Good', 'Car', 'Yes']
# Positive example
# Updated hypothesis: ['?', 'Employed', '?', 'Good', '?']
# Current hypothesis: ['?', 'Employed', '?', 'Good', '?']
#
# Example 4 : ['Youth', 'Employed', 'Medium', 'Good', 'House', 'Yes']
# Positive example
# Updated hypothesis: ['?', 'Employed', '?', 'Good', '?']
# Current hypothesis: ['?', 'Employed', '?', 'Good', '?']
#
# Example 5 : ['Middle-Aged', 'Employed', 'High', 'Good', 'None', 'Yes']
# Positive example
# ...

# %%
#FindS on Large Dataset
import csv

def find_s(data):
    hypothesis = None

    for i, row in enumerate(data, start=1):
        row = [x.strip() for x in row]
        attributes = row[:-1]
        target = row[-1].lower()

        print("\nExample", i, ":", row)

        if target == "yes":
            if hypothesis is None:
                hypothesis = attributes.copy()
                print("Positive example")
                print("Initial hypothesis:", hypothesis)
            else:
                print("Positive example")
                for j in range(len(hypothesis)):
                    if hypothesis[j] != attributes[j]:
                        hypothesis[j] = "?"
                print("Updated hypothesis:", hypothesis)
        else:
            print("Negative example - ignored")

        print("Current hypothesis:", hypothesis)

    return hypothesis


filename = "large_loan_approval_dataset.csv"

with open(filename, "r") as file:
    reader = csv.reader(file)
    header = next(reader)
    data = list(reader)

print("Attributes:", header[:-1])
print("Target:", header[-1])

hypothesis = find_s(data)

print("\nFinal Hypothesis:")
print(hypothesis)
# Out:
# Attributes: ['Age', 'Job', 'Income', 'CreditHistory', 'Collateral']
# Target: Approved
#
# Example 1 : ['Senior', 'Unemployed', 'Low', 'Good', 'Car', 'No']
# Negative example - ignored
# Current hypothesis: None
#
# Example 2 : ['Youth', 'Unemployed', 'Low', 'Good', 'None', 'No']
# Negative example - ignored
# Current hypothesis: None
#
# Example 3 : ['Senior', 'Self-Employed', 'High', 'Bad', 'House', 'No']
# Negative example - ignored
# Current hypothesis: None
#
# Example 4 : ['Middle-Aged', 'Unemployed', 'Low', 'Bad', 'None', 'No']
# Negative example - ignored
# Current hypothesis: None
#
# Example 5 : ['Youth', 'Self-Employed', 'High', 'Bad', 'House', 'No']
# Negative example - ignored
# Current hypothesis: None
#
# Example 6 : ['Youth', 'Self-Employed', 'High', 'Good', 'House', 'Yes']
# Positive example
# Initial hypothesis: ['Youth', 'Self-Employed', 'High', 'Good', 'House']
# Current hypothesis: ['Youth', 'Self-Employed', 'High', 'Good', 'House']
#
# ...
