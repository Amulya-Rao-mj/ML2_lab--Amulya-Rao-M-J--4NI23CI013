# %% [markdown]
# <a href="https://colab.research.google.com/github/Amulya-Rao-mj/machine_learning_lab_2/blob/main/lab1_ML2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("stud.csv")

# %%
print(df)
# Out:
#     Student_ID    Name  Age  Gender  Study_Hours  Attendance  Assignments  \
# 0            1   Aarav   19    Male          5.5        92.0          8.0
# 1            2    Diya   20  Female          7.0        95.0          9.0
# 2            3   Rohan   18    Male          3.5        78.0          6.0
# 3            4  Ananya   19  Female          6.0        88.0          8.0
# 4            5  Vikram   21    Male          4.0        75.0          7.0
# 5            6   Meera   20  Female          8.0        98.0         10.0
# 6            7   Arjun   19    Male          NaN        85.0          7.0
# 7            8   Sneha   18  Female          6.5        90.0          NaN
# 8            9   Karan   22    Male          2.5        65.0          5.0
# 9           10  Ishita   20  Female          7.5        94.0          9.0
# 10          11   Rahul   21    Male          4.5         NaN          6.0
# 11          12   Priya   19  Female          5.0        87.0          8.0
# ...

# %%
df.head()
# Out:
#    Student_ID    Name  Age  Gender  Study_Hours  Attendance  Assignments  \
# 0           1   Aarav   19    Male          5.5        92.0          8.0
# 1           2    Diya   20  Female          7.0        95.0          9.0
# 2           3   Rohan   18    Male          3.5        78.0          6.0
# 3           4  Ananya   19  Female          6.0        88.0          8.0
# 4           5  Vikram   21    Male          4.0        75.0          7.0
#
#    Exam_Score Result
# 0          85   Pass
# 1          91   Pass
# 2          68   Pass
# 3          82   Pass
# 4          70   Pass

# %%
df.tail()
# Out:
#     Student_ID    Name  Age  Gender  Study_Hours  Attendance  Assignments  \
# 15          16   Kavya   19  Female          8.5        99.0         10.0
# 16          17  Sameer   21    Male          5.5        89.0          8.0
# 17          18   Pooja   20  Female          7.0        93.0          9.0
# 18          19   Varun   18    Male          3.5        76.0          6.0
# 19          20    Neha   19  Female          6.5        88.0          8.0
#
#     Exam_Score Result
# 15          98   Pass
# 16          81   Pass
# 17           9   Fail
# 18          23   Fail
# 19          84    NaN

# %%
print(df.dtypes)
# Out:
# Student_ID       int64
# Name            object
# Age              int64
# Gender          object
# Study_Hours    float64
# Attendance     float64
# Assignments    float64
# Exam_Score       int64
# Result          object
# dtype: object

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Study_Hours', 'Attendance',
#        'Assignments', 'Exam_Score', 'Result'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Name           0
# Age            0
# Gender         0
# Study_Hours    1
# Attendance     1
# Assignments    1
# Exam_Score     0
# Result         1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Name           0
# Age            0
# Gender         0
# Study_Hours    0
# Attendance     0
# Assignments    0
# Exam_Score     0
# Result         0
# dtype: int64

# %%
df["Study_Hours"] = df["Study_Hours"].fillna(
    df["Study_Hours"].mean()
)

df["Attendance"] = df["Attendance"].fillna(
    df["Attendance"].mean()
)

df["Assignments"] = df["Assignments"].fillna(
    df["Assignments"].mean())
df.round()
print("Dataset after replacing missing values:")
print(df)
# Out:
# Dataset after replacing missing values:
#     Student_ID    Name  Age  Gender  Study_Hours  Attendance  Assignments  \
# 0            1   Aarav   19    Male          5.5        92.0          8.0
# 1            2    Diya   20  Female          7.0        95.0          9.0
# 2            3   Rohan   18    Male          3.5        78.0          6.0
# 3            4  Ananya   19  Female          6.0        88.0          8.0
# 4            5  Vikram   21    Male          4.0        75.0          7.0
# 5            6   Meera   20  Female          8.0        98.0         10.0
# 8            9   Karan   22    Male          2.5        65.0          5.0
# 9           10  Ishita   20  Female          7.5        94.0          9.0
# 11          12   Priya   19  Female          5.0        87.0          8.0
# 12          13  Aditya   20    Male          3.0        72.0          5.0
# 13          14   Nisha   18  Female          6.0        91.0          8.0
# ...

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_443/2665450381.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance  Assignments  Exam_Score
# count   16.000000  16.000000    16.000000   16.000000    16.000000   16.000000
# mean    10.250000  19.750000     5.406250   85.750000     7.687500   64.687500
# std      6.082763   1.290994     1.863856   10.129166     1.579821   33.589123
# min      1.000000  18.000000     2.500000   65.000000     5.000000    6.000000
# 25%      4.750000  19.000000     3.875000   77.500000     6.750000   50.750000
# 50%     11.000000  20.000000     5.500000   88.500000     8.000000   80.500000
# 75%     15.250000  20.250000     7.000000   93.250000     9.000000   87.250000
# max     19.000000  22.000000     8.500000   99.000000    10.000000   98.000000

# %%
print(df['Exam_Score'].mean())
# Out:
# 64.6875

# %%
import matplotlib.pyplot as plt
plt.hist(df['Exam_Score'],bins=10)
plt.xlabel("Exam Score")
plt.ylabel("Frequency")
plt.title("Histogram of Exam Scores")
plt.show()

# %%
import numpy as np
plt.figure(figsize=(8, 5))

plt.boxplot(df["Exam_Score"])

plt.title("Box Plot of Exam Scores")
plt.ylabel("Exam Score")

plt.show()




numeric_df = df.select_dtypes(include=np.number)

correlation = numeric_df.corr()

print(correlation)
# Out:
#              Student_ID       Age  Study_Hours  Attendance  Assignments  \
# Student_ID     1.000000  0.050937    -0.012496   -0.041117    -0.032953
# Age            0.050937  1.000000    -0.190478   -0.300790    -0.138920
# Study_Hours   -0.012496 -0.190478     1.000000    0.957398     0.974255
# Attendance    -0.041117 -0.300790     0.957398    1.000000     0.961322
# Assignments   -0.032953 -0.138920     0.974255    0.961322     1.000000
# Exam_Score    -0.496864 -0.238681     0.552170    0.550167     0.562127
#
#              Exam_Score
# Student_ID    -0.496864
# Age           -0.238681
# Study_Hours    0.552170
# Attendance     0.550167
# Assignments    0.562127
# Exam_Score     1.000000

# %%
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (16, 9)
# Student_ID     0
# Name           0
# Age            0
# Gender         0
# Study_Hours    0
# Attendance     0
# Assignments    0
# Exam_Score     0
# Result         0
# dtype: int64
# 0
